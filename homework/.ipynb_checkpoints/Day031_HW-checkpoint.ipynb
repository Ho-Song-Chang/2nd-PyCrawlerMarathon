# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %%
import requests
r = requests.get('https://www.ptt.cc/bbs/graduate/index.html')
response = r.text
print(response)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 graduate 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	<script async src='/cdn-cgi/bm/cv/2181903173/api.js'></script></head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# ...

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
header={
    ':authority': 'www.dcard.tw',
    ':method': 'GET',
    ':path': '/f',
    ':scheme': 'https',
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9,zh-TW;q=0.8,zh;q=0.7',
    'cache-control': 'no-cache',
    'cookie': 'dcard=eyJ0b2tlbiI6IlFwZW9nWXNUUmJpN2Rrd2xpdEthSHc9PSIsIl9leHBpcmUiOjE1OTAxNDY4ODU0MDMsIl9tYXhBZ2UiOjI1OTIwMDAwMDB9; dcard.sig=QgBl0oSYmGj4MflryJjkguyJ56I; __auc=0da6db2d171eeb54022d0c5fa51; dcsrd=Q9i6_Cl3X0sKeZVhFqrji6-Q; dcsrd.sig=pT4nBvq5RxzWenkWScMSSlaEL-A; _ga_C3J49QFLW7=GS1.1.1588939520.9.0.1588939520.0; __asc=8f54d8d9171f42cfae50a32ac5b; _ga=GA1.2.1175182993.1587287025; _gid=GA1.2.1678010555.1588939521; _gat=1; amplitude_id_bfb03c251442ee56c07f655053aba20fdcard.tw=eyJkZXZpY2VJZCI6IjZhODc1ZDFjLThlMTYtNDBhNS1iMTEzLWE0YTRmZTUxOGRmN1IiLCJ1c2VySWQiOiIzNDIxNDg0Iiwib3B0T3V0IjpmYWxzZSwic2Vzc2lvbklkIjoxNTg4OTM5NTIxNDM1LCJsYXN0RXZlbnRUaW1lIjoxNTg4OTM5NTIxNDM2LCJldmVudElkIjo2LCJpZGVudGlmeUlkIjoxMSwic2VxdWVuY2VOdW1iZXIiOjE3fQ==; __cfduid=dac9e0c5f714d92108faaf37ddf06e55d1588939522',
    'pragma': 'no-cache',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'no-cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'
}
# Out:
# '\nYour Code Here\n'
